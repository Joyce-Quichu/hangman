# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('matches.csv')

# %%
df.head()
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2   3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3   4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4   5    2008     Kolkata  2008-04-20        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# ...

# %%
df.head(10)
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2   3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3   4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4   5    2008     Kolkata  2008-04-20        Deccan Chargers
# 5   6    2008      Jaipur  2008-04-21        Kings XI Punjab
# 6   7    2008   Hyderabad  2008-04-22        Deccan Chargers
# 7   8    2008     Chennai  2008-04-23    Chennai Super Kings
# 8   9    2008   Hyderabad  2008-04-24        Deccan Chargers
# 9  10    2008  Chandigarh  2008-04-25        Kings XI Punjab
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# ...

# %%
df.tail()
# Out:
#       id  season       city        date                team1  \
# 572  573    2016     Raipur  2016-05-22     Delhi Daredevils
# 573  574    2016  Bangalore  2016-05-24        Gujarat Lions
# 574  575    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 575  576    2016      Delhi  2016-05-27        Gujarat Lions
# 576  577    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 572  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 573  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 574        Kolkata Knight Riders        Kolkata Knight Riders         field
# 575          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 576  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 572  normal           0  Royal Challengers Bangalore            0
# ...

# %%
df.shape
# Out:
# (577, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577 entries, 0 to 576
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               577 non-null    int64
#  1   season           577 non-null    int64
#  2   city             570 non-null    object
#  3   date             577 non-null    object
#  4   team1            577 non-null    object
#  5   team2            577 non-null    object
#  6   toss_winner      577 non-null    object
#  7   toss_decision    577 non-null    object
#  8   result           577 non-null    object
#  9   dl_applied       577 non-null    int64
#  10  winner           574 non-null    object
#  11  win_by_runs      577 non-null    int64
#  12  win_by_wickets   577 non-null    int64
#  13  player_of_match  574 non-null    object
#  14  venue            577 non-null    object
#  15  umpire1          577 non-null    object
#  16  umpire2          577 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              0
# umpire2              0
# umpire3            577
# dtype: int64

# %%
df=df.drop('umpire3',axis=1)
df
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1      2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3      4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4      5    2008     Kolkata  2008-04-20        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577 entries, 0 to 576
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               577 non-null    int64
#  1   season           577 non-null    int64
#  2   city             570 non-null    object
#  3   date             577 non-null    object
#  4   team1            577 non-null    object
#  5   team2            577 non-null    object
#  6   toss_winner      577 non-null    object
#  7   toss_decision    577 non-null    object
#  8   result           577 non-null    object
#  9   dl_applied       577 non-null    int64
#  10  winner           574 non-null    object
#  11  win_by_runs      577 non-null    int64
#  12  win_by_wickets   577 non-null    int64
#  13  player_of_match  574 non-null    object
#  14  venue            577 non-null    object
#  15  umpire1          577 non-null    object
#  16  umpire2          577 non-null    object
# ...

# %%
df=df.dropna()

# %%
df
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1      2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3      4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4      5    2008     Kolkata  2008-04-20        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 567 entries, 0 to 576
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               567 non-null    int64
#  1   season           567 non-null    int64
#  2   city             567 non-null    object
#  3   date             567 non-null    object
#  4   team1            567 non-null    object
#  5   team2            567 non-null    object
#  6   toss_winner      567 non-null    object
#  7   toss_decision    567 non-null    object
#  8   result           567 non-null    object
#  9   dl_applied       567 non-null    int64
#  10  winner           567 non-null    object
#  11  win_by_runs      567 non-null    int64
#  12  win_by_wickets   567 non-null    int64
#  13  player_of_match  567 non-null    object
#  14  venue            567 non-null    object
#  15  umpire1          567 non-null    object
#  16  umpire2          567 non-null    object
# ...

# %%
#creating a bar plot for the 10 top players
plt.figure(figsize=(10))
plt.title('players of the match',fontsize=16,fontstyle='italics')
plt.bar(x=players,width=0.6,color='red',edgecolor='k',alpha=0.6)
plt.xlabel('players',fontsize(10))
plt.xticks(fontsize=10)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-cabbd23c9d0b> in <module>
#       1 #creating a bar plot for the 10 top players
# ----> 2 plt.figure(figsize=(10))
#       3 plt.title('players of the match',fontsize=16,fontstyle='italics')
#       4 plt.bar(x=players,width=0.6,color='red',edgecolor='k',alpha=0.6)
#       5 plt.xlabel('players',fontsize(10))
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     538             dpi = 72
#     539
# --> 540         figManager = new_figure_manager(num, figsize=figsize,
#     541                                         dpi=dpi,
#     542                                         facecolor=facecolor,
#
# ...

# %%
df.player_of_match.value_counts()
# Out:
# CH Gayle          17
# YK Pathan         16
# AB de Villiers    15
# DA Warner         14
# RG Sharma         13
#                   ..
# RS Bopara          1
# MR Marsh           1
# JDP Oram           1
# GD McGrath         1
# A Singh            1
# Name: player_of_match, Length: 186, dtype: int64

# %%
df.player_of_match.value_counts()[:10].plot(kind='bar')

# %%
df.winner.value_counts('top winner')[:3].plot(kind='bar')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 567 entries, 0 to 576
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               567 non-null    int64
#  1   season           567 non-null    int64
#  2   city             567 non-null    object
#  3   date             567 non-null    object
#  4   team1            567 non-null    object
#  5   team2            567 non-null    object
#  6   toss_winner      567 non-null    object
#  7   toss_decision    567 non-null    object
#  8   result           567 non-null    object
#  9   dl_applied       567 non-null    int64
#  10  winner           567 non-null    object
#  11  win_by_runs      567 non-null    int64
#  12  win_by_wickets   567 non-null    int64
#  13  player_of_match  567 non-null    object
#  14  venue            567 non-null    object
#  15  umpire1          567 non-null    object
#  16  umpire2          567 non-null    object
# ...

# %%
df.toss_winner.value_counts()[:5].plot(kind='bar')
